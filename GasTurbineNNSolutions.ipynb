# %% [markdown]
# # <center><u> Gas Turbine Neural Network Solutions:</u>

# %% [markdown]
# ### Importing the basic libraries and reading the dataset:

# %%
import pandas as pd
dataset = pd.read_csv('/content/gas_turbines.csv')
dataset.head(5)
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
dataset.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %% [markdown]
# ## EDA:

# %%
print("Statistical Description:", dataset.describe())
# Out:
# Statistical Description:                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %%
print("Shape:", dataset.shape)
# Out:
# Shape: (15039, 11)

# %%
print("Data Types:", dataset.dtypes)
# Out:
# Data Types: AT      float64
# AP      float64
# AH      float64
# AFDP    float64
# GTEP    float64
# TIT     float64
# TAT     float64
# TEY     float64
# CDP     float64
# CO      float64
# NOX     float64
# dtype: object

# %% [markdown]
# ### Data Visualization:

# %%
dataset.hist(figsize = (15,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ca412d2d0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset.corr()["TEY"].sort_values(ascending=False)
# Out:
# TEY     1.000000
# CDP     0.988473
# GTEP    0.977042
# TIT     0.891587
# AFDP    0.717995
# AP      0.146939
# NOX    -0.102631
# AH     -0.110272
# AT     -0.207495
# CO     -0.541751
# TAT    -0.720356
# Name: TEY, dtype: float64

# %%
numerical_features = dataset.describe(include=["int64","float64"]).columns
numerical_features
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
sns.distplot(dataset['AT'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['AP'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['AH'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['AFDP'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['GTEP'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['TIT'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['TAT'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['TEY'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['CDP'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['CO'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['NOX'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Some of the features are normally distributed. The features AH, CO, TITy and TATa exhibit the highest skew coefficients. Moreover, the distribution of Carbon Mono oxide (CO) and Turbine inlet temperature (TIT) and Turbine after temperature (TAT) seem to contain many outliers. Let's identify the indices of the observations containing outliers using Turkey's method.

# %%
ot=dataset.copy() 
fig, axes =plt.subplots(11,1,figsize=(14,16),sharex=False,sharey=False)
sns.boxplot(x='AT',data=ot,palette='crest',ax=axes[0])
sns.boxplot(x='AP',data=ot,palette='crest',ax=axes[1])
sns.boxplot(x='AH',data=ot,palette='crest',ax=axes[2])
sns.boxplot(x='AFDP',data=ot,palette='crest',ax=axes[3])
sns.boxplot(x='GTEP',data=ot,palette='crest',ax=axes[4])
sns.boxplot(x='TIT',data=ot,palette='crest',ax=axes[5])
sns.boxplot(x='TAT',data=ot,palette='crest',ax=axes[6])
sns.boxplot(x='TEY',data=ot,palette='crest',ax=axes[7])
sns.boxplot(x='CDP',data=ot,palette='crest',ax=axes[8])
sns.boxplot(x='CO',data=ot,palette='crest',ax=axes[9])
sns.boxplot(x='NOX',data=ot,palette='crest',ax=axes[10])
plt.tight_layout(pad=2.0)

# %%
#outlier
plt.figure(figsize=(20,16))
sns.boxplot(data=dataset[numerical_features], orient="h")

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,10))
sns.histplot(data=dataset,x="TEY",color="red",kde=True)
plt.axvline(x=dataset["TEY"].mean(),ymax=0.55,color="green",linestyle='--',label="Mean")
plt.axvline(x=dataset["TEY"].median(),ymax=0.56,color="purple",linestyle='--',label="Median")
plt.legend()
plt.title("Histogram of the Target Column")
# Out:
# Text(0.5, 1.0, 'Histogram of the Target Column')

# %%
plt.figure(figsize = (12,10))
sns.histplot(dataset["TEY"],kde=True,bins=40,color="red",cumulative=True)
plt.title("Cumulative of the Target Column")
# Out:
# Text(0.5, 1.0, 'Cumulative of the Target Column')

# %%
for i in dataset.columns:
    if i!="TEY": 
        plt.scatter(np.log(dataset[i]), np.log(dataset['TEY']))
        plt.title(i+ ' vs TEY')
        plt.grid()
        plt.show()

# %%
plt.figure(figsize=(20,20))
sns.pairplot(dataset,
                 markers="+",
                 kind='reg',
                 diag_kind="kde",
                 plot_kws={'line_kws':{'color':'#aec6cf'},
                           'scatter_kws': {'alpha': 0.5,
                                           'color': '#82ad32'}},
               corner=True,
                 diag_kws= {'color': '#82ad32'})

# %%
dataset.plot(kind='density', subplots=True, layout=(7,7), sharex=False, sharey=False, )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c93a8cbd0>,
# ...
#       dtype=object)

# %%
dataset.plot(kind='box', subplots=True, layout=(9,4), sharex=False, sharey=False)
# Out:
# AT         AxesSubplot(0.125,0.808774;0.168478x0.0712264)
# AP      AxesSubplot(0.327174,0.808774;0.168478x0.0712264)
# AH      AxesSubplot(0.529348,0.808774;0.168478x0.0712264)
# AFDP    AxesSubplot(0.731522,0.808774;0.168478x0.0712264)
# GTEP       AxesSubplot(0.125,0.723302;0.168478x0.0712264)
# TIT     AxesSubplot(0.327174,0.723302;0.168478x0.0712264)
# TAT     AxesSubplot(0.529348,0.723302;0.168478x0.0712264)
# TEY     AxesSubplot(0.731522,0.723302;0.168478x0.0712264)
# CDP         AxesSubplot(0.125,0.63783;0.168478x0.0712264)
# CO       AxesSubplot(0.327174,0.63783;0.168478x0.0712264)
# NOX      AxesSubplot(0.529348,0.63783;0.168478x0.0712264)
# dtype: object

# %%
pd.plotting.scatter_matrix(dataset)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9242d4d0>,
# ...
#       dtype=object)

# %%
import numpy as np
fig = plt.figure(figsize = (15,7))
ax = fig.add_subplot(111)
cax = ax.matshow(dataset.corr(), vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,13,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(dataset.columns)
ax.set_yticklabels(dataset.columns)
# Out:
# [Text(0, 0, 'AT'),
#  Text(0, 0, 'AP'),
#  Text(0, 0, 'AH'),
#  Text(0, 0, 'AFDP'),
#  Text(0, 0, 'GTEP'),
#  Text(0, 0, 'TIT'),
#  Text(0, 0, 'TAT'),
#  Text(0, 0, 'TEY'),
#  Text(0, 0, 'CDP'),
#  Text(0, 0, 'CO'),
#  Text(0, 0, 'NOX')]

# %% [markdown]
# ## Creating the model:

# %%
import tensorflow as tf
dataset.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
X = dataset.drop(columns = ['TEY'], axis = 1).values

# %%
y = dataset.iloc[:,7].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1))

# %%
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 376/376 [==============================] - 2s 2ms/step - loss: 509.6737
# Epoch 2/100
# 376/376 [==============================] - 1s 3ms/step - loss: 295.0621
# Epoch 3/100
# 376/376 [==============================] - 1s 2ms/step - loss: 204.3482
# Epoch 4/100
# 376/376 [==============================] - 1s 2ms/step - loss: 132.7244
# Epoch 5/100
# 376/376 [==============================] - 0s 1ms/step - loss: 77.8279
# Epoch 6/100
# 376/376 [==============================] - 1s 2ms/step - loss: 44.9745
# Epoch 7/100
# 376/376 [==============================] - 1s 2ms/step - loss: 28.0145
# Epoch 8/100
# 376/376 [==============================] - 1s 2ms/step - loss: 18.9627
# Epoch 9/100
# 376/376 [==============================] - 1s 2ms/step - loss: 14.3300
# Epoch 10/100
# 376/376 [==============================] - 0s 1ms/step - loss: 10.8994
# Epoch 11/100
# 376/376 [==============================] - 0s 1ms/step - loss: 8.7291
# Epoch 12/100
# ...

# %%
y_pred = ann.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[134.66 134.06]
#  [156.53 155.98]
#  [133.16 133.77]
#  ...
#  [133.17 133.23]
#  [133.05 134.71]
#  [133.12 133.76]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_predict_test = ann.predict(X_test)
y_predict_train = ann.predict(X_train) 
print('R2_score (train): ',r2_score(y_train, y_predict_train))
print('R2_score (test): ',r2_score(y_test, y_predict_test))
# Out:
# R2_score (train):  0.9947311021805244
# R2_score (test):  0.9948105337483408
